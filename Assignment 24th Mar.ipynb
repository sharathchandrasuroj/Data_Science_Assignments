# %% [markdown]
# ### Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in predicting the quality of wine.

# %%
import pandas as pd
df=pd.read_csv('winequality-red.csv')
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df.corr('spearman')
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.201727     0.269576
# volatile acidity           0.201727          1.000000    -0.295214
# citric acid                0.269576         -0.295214     1.000000
# residual sugar            -0.032594         -0.065533     0.075108
# chlorides                  0.356560          0.416103    -0.073582
# free sulfur dioxide       -0.260912         -0.366622     0.122375
# total sulfur dioxide      -0.234317         -0.344299     0.159302
# density                    0.434410          0.261129     0.065790
# pH                        -0.248424          0.193986    -0.284699
# sulphates                  0.221359          0.254747     0.038258
# alcohol                   -0.110731         -0.024037     0.019774
# quality                   -0.098669         -0.258272     0.105916
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [raw]
# The wine quality data set contains information on various physicochemical properties of different types of wines, along with their associated
# quality ratings. Here are the key features of the data set and their importance in predicting the quality of wine:
#
#
# Fixed acidity:
# This refers to the amount of acids, such as tartaric acid, that are present in the wine. It is an important feature as it can
# impact the perceived taste and balance of the wine. Wines with too high or too low fixed acidity levels can be perceived as either too tart or
# too flat.
#
# Volatile acidity:
# This feature measures the amount of volatile acids, such as acetic acid, in the wine. High levels of volatile acidity can make
# the wine smell like vinegar, which is not desirable.
#
# Citric acid:
# This is a type of acid that is found in citrus fruits and can contribute to the overall balance of the wine. It is important to
# have the right amount of citric acid in the wine to avoid it being too sweet or too sour.
#
# Residual sugar:
# This feature refers to the amount of sugar that remains in the wine after fermentation. It is an important factor in determining
# the sweetness of the wine and can impact its perceived quality.
#
# Chlorides:
# This feature measures the amount of salt in the wine. It can contribute to the wine's overall flavor profile, but too much can make
# it taste salty or briny.
#
# Free sulfur dioxide:
# This feature measures the amount of sulfur dioxide, which is used as a preservative, that is present in the wine.
# It is important to have the right amount of free sulfur dioxide in the wine to prevent spoilage.
#
# Total sulfur dioxide:
# This feature measures the total amount of sulfur dioxide in the wine, including both free and bound sulfur dioxide.
# It is an important factor in determining the wine's stability and shelf life.
#
# Density:
# This feature measures the density of the wine, which can be influenced by the alcohol content, residual sugar, and other factors.
# It is an important factor in determining the body and mouthfeel of the wine.
#
# pH:
# This feature measures the acidity or alkalinity of the wine. It is important to have the right pH level in the wine to avoid spoilage and to
# contribute to its overall balance and flavor profile.
#
# Sulphates:
# This feature measures the amount of sulphates, which are often added to wines as a preservative, that are present in the wine.
# It can impact the wine's flavor and aroma profile.
#
# Alcohol:
# This feature measures the alcohol content of the wine, which can influence its body, flavor, and perceived quality.
# Wines with too high or too low alcohol content can be perceived as unbalanced.
#
#
# All of these features are important in predicting the quality of wine as they contribute to the wine's overall flavor, aroma, balance, and stability.
# By analyzing these features and their relationships to each other, it is possible to develop predictive models that can help determine the quality
# of different types of wine.

# %% [markdown]
# ### Q2. How did you handle missing data in the wine quality data set during the feature engineering process? Discuss the advantages and disadvantages of different imputation techniques.

# %%
df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %% [raw]
# Missing data is a common issue in many datasets, including the wine quality dataset. It can be caused by various factors such as data entry errors,
# incomplete data collection, or data loss during transmission. In order to handle missing data in the dataset during the feature engineering
# process, one can use different imputation techniques. These techniques involve replacing missing values with estimated values based on the
# other available data in the dataset.
#
#
#
#
# Here are some of the most common imputation techniques and their advantages and disadvantages:
#
#
# 1.Mean imputation: This technique involves replacing missing values with the mean value of the feature. Mean imputation is simple to implementand can preserve the overall distribution of the feature. However, it can also introduce bias into the dataset, especially if the feature has a skewed distribution.
#
# 2.Median imputation: This technique involves replacing missing values with the median value of the feature. Median imputation is also simple to implement and can be more robust to outliers than mean imputation. However, like mean imputation, it can also introduce bias into the dataset.
#
# 3.K-nearest neighbor imputation: This technique involves finding the K nearest neighbors of the sample with missing values and using their values to impute the missing data. K-nearest neighbor imputation can be more accurate than mean or median imputation as it takes into account the relationships between different features in the dataset. However, it can also be computationally expensive and sensitive to the choice of K.
#
# 4.Multiple imputation: This technique involves creating multiple imputations of the missing data based on a statistical model of the dataset. Multiple imputation can be more accurate than single imputation techniques as it accounts for the uncertainty in the missing data. However, it can also be computationally expensive and requires a good understanding of the underlying statistical model.
#
# 5.Regression imputation: This technique involves using a regression model to predict the missing values based on the other features in the dataset.Regression imputation can be more accurate than mean or median imputation as it takes into account the relationships between different features in the dataset. However, it can also introduce bias if the regression model is misspecified.

# %% [markdown]
# ### Q3. What are the key factors that affect students' performance in exams? How would you go about analyzing these factors using statistical techniques?

# %% [raw]
# There are many factors that can affect a student's performance in exams.
# Some of the key factors include:
#
# -Prior knowledge: Students who have a strong foundation in the subject matter are more likely to perform well on exams.
#
# -Study habits: Students who develop effective study habits, such as managing their time well and studying regularly, are more likely to perform well on exams.
#
# -Motivation: Students who are motivated and have a strong desire to do well are more likely to perform well on exams.
#
# -Test anxiety: Students who experience high levels of test anxiety may perform poorly on exams, even if they have a strong foundation in the subject matter.
#
# -Teacher quality: The quality of teaching can also affect student performance on exams.

# %% [markdown]
# ### Q4. Describe the process of feature engineering in the context of the student performance data set. How did you select and transform the variables for your model?

# %% [markdown]
# Once these variables have been selected, they can be transformed to make them more informative.
#
# Some common transformations include:
#
# #Scaling: This involves rescaling a variable to a common range, such as between 0 and 1, to allow for easier comparison with other variables.
#
#
# #One-hot encoding: This involves creating binary variables for categorical variables, such as gender or race, to allow them to be used in a model.
#
#
# #Feature interaction: This involves creating new variables by combining existing variables, such as multiplying prior academic performance by study habits, to capture interactions between variables.
#
#
# #Feature selection: This involves selecting the most informative variables for a model, using techniques such as principal component analysis or stepwise regression.

# %% [markdown]
# ### Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to these features to improve normality?

# %%
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
l=list(i for i in df.columns if(df[i].dtypes!='O'))
l
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline
## Proportion of count data on numerical columns
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(l)):
    plt.subplot(4, 3, i+1)
    sns.kdeplot(x=df[l[i]],shade=True, color='r')
    plt.xlabel(l[i])
    plt.tight_layout()

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(l)):
    plt.subplot(4, 3, i+1)
    sns.boxplot(df[l[i]])
    plt.xlabel(l[i])
    plt.tight_layout()

# %%
#Therefore normalization we can apply removal of outliers by replacing it bu mode

# %%
from numpy import percentile

# %% [raw]
# from numpy import percentile
# import pandas as pd
#
# # Assuming 'df' is your DataFrame
#
# l = list(df.columns)
#
# for i in l:
#     lst = df[i].to_list()
#
#     Q1, Q2, Q3 = int(percentile(lst, [25, 50, 75])  # Fix: Use percentile on the list 'lst'
#     IQR = Q3-Q1
#     LOWER_FENCE = Q1 - (1.5 * IQR)
#     HIGHER_FENCE = Q3 + (1.5 * IQR)
#
#     for j in range(len(lst)):
#         if (lst[j] > HIGHER_FENCE) or (lst[j] < LOWER_FENCE):
#             # Check if the mode exists
#             if not df[i].mode().empty:
#                 # Replace outliers with the mode
#                 lst[j] = df[i].mode()[0]
#             else:
#                 # If mode doesn't exist, you may consider using median or mean
#                 lst[j] = df[i].median()
#
#     df[i] = lst

# %% [raw]
# plt.figure(figsize=(15, 15))
# plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
#
# for i in range(0, len(l)):
#     plt.subplot(4, 3, i+1)
#     sns.boxplot(df[l[i]])
#     plt.xlabel(l[i])
#     plt.tight_layout()

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(l)):
    plt.subplot(4, 3, i+1)
    sns.kdeplot(x=df[l[i]],shade=True, color='r')
    plt.xlabel(l[i])
    plt.tight_layout()

# %% [markdown]
# ### Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of features. What is the minimum number of principal components required to explain 90% of the variance in the data?

# %%
df.corr('spearman')
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.201727     0.269576
# volatile acidity           0.201727          1.000000    -0.295214
# citric acid                0.269576         -0.295214     1.000000
# residual sugar            -0.032594         -0.065533     0.075108
# chlorides                  0.356560          0.416103    -0.073582
# free sulfur dioxide       -0.260912         -0.366622     0.122375
# total sulfur dioxide      -0.234317         -0.344299     0.159302
# density                    0.434410          0.261129     0.065790
# pH                        -0.248424          0.193986    -0.284699
# sulphates                  0.221359          0.254747     0.038258
# alcohol                   -0.110731         -0.024037     0.019774
# quality                   -0.098669         -0.258272     0.105916
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
from sklearn.decomposition import PCA

# %%
import numpy as np

# %%
data=np.array([df['volatile acidity'],df['sulphates'],df['alcohol'],df['chlorides'],df['total sulfur dioxide']])

# %% [raw]
# pca = PCA(n_components=2)
# pca.fit(data)

# %%
PCA(n_components=2)
In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org.

# %%
pca.explained_variance_ratio_

# %%
pca.singular_values_
