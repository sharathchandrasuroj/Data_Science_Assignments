# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [raw]
# -It is very famous python framewrok
# -Which allows us to communicate or connect two totally different codes
# -This is basically set ups web server through which we can access web applications
# -This vry useful incase of projetcs where everyone has diffrent role till they can connect each other

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# Unfortunately, I can't directly execute Flask applications or attach screenshots in this text-based environment. However, I can guide you on how to create a simple Flask application to display "Hello World!!".

# %% [raw]
# Firstly, make sure you have Flask installed. If not, you can install it using:
#     pip install flask

# %% [raw]
# Now, create a Python file (e.g., app.py) with the following content:
#
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route('/')
# def hello_world():
#     return 'Hello World!!'
#
# if __name__ == '__main__':
#     app.run(debug=True)

# %% [raw]
# Save the file and run it in your terminal or command prompt:
#
#
# python app.py

# %% [raw]
# This will start the Flask development server. Open your web browser and go to http://127.0.0.1:5000/. You should see "Hello World!!" displayed on the page.

# %% [raw]
# Here's an example using IPython's HTML class:
#
#
# from IPython.core.display import HTML
#
# HTML('<iframe src="http://127.0.0.1:5000/" width="800" height="600"></iframe>')

# %% [markdown]
# ![19th%20feb1.png](attachment:19th%20feb1.png)

# %% [markdown]
# ![19th%20feb2.png](attachment:19th%20feb2.png)

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %% [raw]
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route('/')
# def hello_world():
#     return 'Hello World!!'
#
# if __name__ == '__main__':
#     app.run(debug=True)

# %% [markdown]
# ![19th%20feb2.png](attachment:19th%20feb2.png)

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?

# %% [raw]
# #App routing is concept ofgenerating url for the function we created
# #With the help of app routing our appication becomes bound less
# #We can run and access the function on any device in the world
# #This is beacuse of app routing which we did for the function

# %% [markdown]
# ### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details: Company Name: ABC Corporation Location: India Contact Detail: 999-999-9999 Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# ![19th%20feb3.png](attachment:19th%20feb3.png)

# %% [markdown]
# ### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [raw]
# #url_for() function is used for url building in flask
# #This function redirects to other url for which we built function
# #This url_for() helps us to connect with multiple url
# #This function also take function argument as a input along with url

# %% [raw]
# from flask import Flask, redirect, url_for
#
# app = Flask(__name__)
#
# @app.route("/")
# def new():
#     return "Hiii welcome!!!"
#
# @app.route("/welcome")
# def old():
#     return redirect(url_for('new'))
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")
